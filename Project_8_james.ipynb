# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
import random
from sklearn.tree import export_graphviz
from IPython.display import SVG

from sklearn.tree import export_graphviz
import graphviz


# You may need to install the Python graphviz library. At the command line:
#   pip install graphviz
# You will also need to install the graphviz executables. You can use apt,
# macports, or other installer for your system.


import matplotlib.pyplot as plt

import os
os.environ["PATH"] += os.pathsep + r'C:\Users\James\Downloads\windows_10_msbuild_Release_graphviz-8.0.1-win32\Graphviz\bin'

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Comma-separated values
breasts_tumor = pd.read_csv('data.csv')
breasts_tumor['cancer_or_not']= breasts_tumor['diagnosis']=='M'
breasts_tumor['cancer_or_not'] = breasts_tumor['cancer_or_not'].astype(int)


breasts_tumor.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
feature_cols=['radius_mean','texture_mean','perimeter_mean','area_mean']
x= breasts_tumor[feature_cols]
y= breasts_tumor.cancer_or_not

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

treeclf = DecisionTreeClassifier(max_depth=3, random_state=1)
treeclf.fit(x, y)

graph = graphviz.Source(tree.export_graphviz(treeclf, out_file=None,
                                    feature_names=feature_cols,
                                    class_names=['0', '1', '2', '3'], filled = True))
svg = SVG(graph.pipe(format='svg'))
display(svg)

# %%
feature_cols=['perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst']
x= breasts_tumor[feature_cols]
y= breasts_tumor.cancer_or_not

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

treeclf = DecisionTreeClassifier(max_depth=7, random_state=1)
treeclf.fit(x, y)

graph = graphviz.Source(tree.export_graphviz(treeclf, out_file=None,
                                    feature_names=feature_cols,
                                    class_names=['0', '1', '2', '3','4','5','6'], filled = True))
svg = SVG(graph.pipe(format='svg'))
display(svg)
